# %%
liked_books = ["4408", "31147619", "29983711", "9401317", "9317691", "8153988", "20494944"]

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
len(csv_book_mapping)
# Out:
# 2360651

# %%
# !wc -l goodreads_interactions.csv
# Out:
#  228648343 goodreads_interactions.csv

# %%
# !ls -lh | grep goodreads_interactions
# Out:
# -rw-r--r--@ 1 william  staff   4.0G May  8 16:57 goodreads_interactions.csv

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %%
with open("goodreads_interactions.csv", "r") as f:
    line = f.readline()
    line = f.readline()
user_id, csv_id, _, rating, _ = line.split(",")

rating = int(rating)

book_id = csv_book_mapping[csv_id]
book_id
# Out:
# '12'

# %%
overlap_users = set()

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        #if already in overlap user set stop processing
        if user_id in overlap_users:
            continue 
        
        #parse rating out as an integer
        try:
            rating = int(rating)
            
        except ValueError:
            continue
            
        #convert csv id to book id using dictionary from earlier
        book_id = csv_book_mapping[csv_id]
        
        #add user to overlap users based on both conditions below
        if book_id in liked_books and rating >=4:
            overlap_users.add(user_id)

# %%
rec_lines = []
with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
    
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
len(overlap_users)
# Out:
# 2029

# %%
len(rec_lines)
# Out:
# 1530257

# %%
import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %%
top_recs = recs["book_id"].value_counts().head(10)
top_recs = top_recs.index.values

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#           book_id                                              title  ratings  \
# 53027       77203                                    The Kite Runner  1848782
# 284473    2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 401395       5107                             The Catcher in the Rye  2086945
# 463463       4671                                   The Great Gatsby  2758812
# 615314       5470                                               1984  2023937
# 757376      38447                                The Handmaid's Tale   648783
# 790927       2657                              To Kill a Mockingbird  3255518
# 878151   18143977                        All the Light We Cannot See   498685
# 878545          3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 1062354  29983711                                           Pachinko     8161
#
#                                                        url  \
# 53027    https://www.goodreads.com/book/show/77203.The_...
# 284473   https://www.goodreads.com/book/show/2767052-th...
# 401395   https://www.goodreads.com/book/show/5107.The_C...
# 463463   https://www.goodreads.com/book/show/4671.The_G...
# 615314       https://www.goodreads.com/book/show/5470.1984
# 757376   https://www.goodreads.com/book/show/38447.The_...
# 790927   https://www.goodreads.com/book/show/2657.To_Ki...
# 878151   https://www.goodreads.com/book/show/18143977-a...
# 878545   https://www.goodreads.com/book/show/3.Harry_Po...
# 1062354  https://www.goodreads.com/book/show/29983711-p...
#
#                                                cover_image  \
# 53027    https://images.gr-assets.com/books/1484565687m...
# 284473   https://images.gr-assets.com/books/1447303603m...
# 401395   https://images.gr-assets.com/books/1398034300m...
# 463463   https://images.gr-assets.com/books/1490528560m...
# 615314   https://images.gr-assets.com/books/1348990566m...
# 757376   https://images.gr-assets.com/books/1498057733m...
# 790927   https://images.gr-assets.com/books/1361975680m...
# 878151   https://images.gr-assets.com/books/1451445646m...
# 878545   https://images.gr-assets.com/books/1474154022m...
# 1062354  https://images.gr-assets.com/books/1462393298m...
#
#                                                  mod_title
# 53027                                      the kite runner
# 284473                 the hunger games the hunger games 1
# 401395                              the catcher in the rye
# 463463                                    the great gatsby
# 615314                                                1984
# 757376                                  the handmaids tale
# 790927                               to kill a mockingbird
# 878151                         all the light we cannot see
# 878545   harry potter and the sorcerers stone harry pot...
# 1062354                                           pachinko

# %%
all_recs = recs["book_id"].value_counts()

# %%
all_recs
# Out:
# 2767052     1092
# 29983711    1089
# 2657        1074
# 3           1048
# 4671        1028
#             ...
# 21843400       1
# 18595019       1
# 22514204       1
# 22733082       1
# 18781576       1
# Name: book_id, Length: 364169, dtype: int64

# %%
all_recs = all_recs.to_frame().reset_index()

# %%
all_recs
# Out:
#            index  book_id
# 0        2767052     1092
# 1       29983711     1089
# 2           2657     1074
# 3              3     1048
# 4           4671     1028
# ...          ...      ...
# 364164  21843400        1
# 364165  18595019        1
# 364166  22514204        1
# 364167  22733082        1
# 364168  18781576        1
#
# [364169 rows x 2 columns]

# %%
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs
# Out:
#          book_id  book_count
# 0        2767052        1092
# 1       29983711        1089
# 2           2657        1074
# 3              3        1048
# 4           4671        1028
# ...          ...         ...
# 364164  21843400           1
# 364165  18595019           1
# 364166  22514204           1
# 364167  22733082           1
# 364168  18781576           1
#
# [364169 rows x 2 columns]

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_recs
# Out:
#          book_id  book_count  \
# 0        2767052        1092
# 1       29983711        1089
# 2           2657        1074
# 3              3        1048
# 4           4671        1028
# ...          ...         ...
# 328338  22707746           1
# 328339  21843400           1
# 328340  18595019           1
# 328341  22514204           1
# 328342  18781576           1
#
#                                                     title  ratings  \
# 0                 The Hunger Games (The Hunger Games, #1)  4899965
# 1                                                Pachinko     8161
# 2                                   To Kill a Mockingbird  3255518
# 3       Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 4                                        The Great Gatsby  2758812
# ...                                                   ...      ...
# 328338                            Names Can Never Hurt Me      297
# 328339  Blackbird Knitting in a Bunny's Lair (Granby K...      604
# 328340                                           Bar None       25
# 328341                   Unexpected Trust (Unexpected #2)      121
# 328342                           Wolverine: Old Man Logan      891
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/2767052-th...
# 1       https://www.goodreads.com/book/show/29983711-p...
# 2       https://www.goodreads.com/book/show/2657.To_Ki...
# 3       https://www.goodreads.com/book/show/3.Harry_Po...
# 4       https://www.goodreads.com/book/show/4671.The_G...
# ...                                                   ...
# 328338  https://www.goodreads.com/book/show/22707746-n...
# 328339  https://www.goodreads.com/book/show/21843400-b...
# 328340  https://www.goodreads.com/book/show/18595019-b...
# 328341  https://www.goodreads.com/book/show/22514204-u...
# 328342  https://www.goodreads.com/book/show/18781576-w...
#
#                                               cover_image  \
# 0       https://images.gr-assets.com/books/1447303603m...
# 1       https://images.gr-assets.com/books/1462393298m...
# 2       https://images.gr-assets.com/books/1361975680m...
# 3       https://images.gr-assets.com/books/1474154022m...
# 4       https://images.gr-assets.com/books/1490528560m...
# ...                                                   ...
# 328338  https://images.gr-assets.com/books/1405051347m...
# 328339  https://images.gr-assets.com/books/1396575651m...
# 328340  https://images.gr-assets.com/books/1380480671m...
# 328341  https://images.gr-assets.com/books/1403721300m...
# 328342  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                                 mod_title
# 0                     the hunger games the hunger games 1
# 1                                                pachinko
# 2                                   to kill a mockingbird
# 3       harry potter and the sorcerers stone harry pot...
# 4                                        the great gatsby
# ...                                                   ...
# 328338                            names can never hurt me
# 328339  blackbird knitting in a bunnys lair granby kni...
# 328340                                           bar none
# 328341                      unexpected trust unexpected 2
# 328342                            wolverine old man logan
#
# [328343 rows x 7 columns]

# %%
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#        book_id  book_count                                              title  \
# 1     29983711        1089                                           Pachinko
# 238       4408         327                                       East of Eden
# 724    9317691         175  The Name of the Wind (The Kingkiller Chronicle...
# 236   32920226         328                               Sing, Unburied, Sing
# 216   30753987         342                                        The Leavers
# 7617  26856502          27                            Vengeful (Villains, #2)
# 1287  31147619         118                                          Homegoing
# 5517  34927828          37                                    The Great Alone
# 249    8153988         322           The Eye of the World (Wheel of Time, #1)
# 6011  35099035          34                                         Red Clocks
#
#       ratings                                                url  \
# 1        8161  https://www.goodreads.com/book/show/29983711-p...
# 238      3447  https://www.goodreads.com/book/show/4408.East_...
# 724      1043  https://www.goodreads.com/book/show/9317691-th...
# 236      4592  https://www.goodreads.com/book/show/32920226-s...
# 216      5602  https://www.goodreads.com/book/show/30753987-t...
# 7617       35  https://www.goodreads.com/book/show/26856502-v...
# 1287      697  https://www.goodreads.com/book/show/31147619-h...
# 5517       70  https://www.goodreads.com/book/show/34927828-t...
# 249      5740  https://www.goodreads.com/book/show/8153988-th...
# 6011       67  https://www.goodreads.com/book/show/35099035-r...
#
#                                             cover_image  \
# 1     https://images.gr-assets.com/books/1462393298m...
# 238   https://images.gr-assets.com/books/1323882457m...
# 724   https://images.gr-assets.com/books/1360558233m...
# 236   https://images.gr-assets.com/books/1499340866m...
# 216   https://images.gr-assets.com/books/1489158974m...
# 7617  https://s.gr-assets.com/assets/nophoto/book/11...
# 1287  https://images.gr-assets.com/books/1491119004m...
# 5517  https://images.gr-assets.com/books/1501852384m...
# 249   https://images.gr-assets.com/books/1465920672m...
# 6011  https://images.gr-assets.com/books/1494345016m...
#
#                                             mod_title       score
# 1                                            pachinko  145.315648
# 238                                      east of eden   31.020888
# 724   the name of the wind the kingkiller chronicle 1   29.362416
# 236                                sing unburied sing   23.428571
# 216                                       the leavers   20.878972
# 7617                              vengeful villains 2   20.828571
# 1287                                        homegoing   19.977044
# 5517                                  the great alone   19.557143
# 249              the eye of the world wheel of time 1   18.063415
# 6011                                       red clocks   17.253731

# %%
popular_recs = all_recs[all_recs["book_count"] > 75].sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url':make_clickable, 'cover_image':show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbf73_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >book_count</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >ratings</th>
#       <th class="col_heading level0 col4" >url</th>
#       <th class="col_heading level0 col5" >cover_image</th>
#       <th class="col_heading level0 col6" >mod_title</th>
#       <th class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbf73_level0_row0" class="row_heading level0 row0" >236</th>
#       <td id="T_dbf73_row0_col0" class="data row0 col0" >32920226</td>
#       <td id="T_dbf73_row0_col1" class="data row0 col1" >328</td>
#       <td id="T_dbf73_row0_col2" class="data row0 col2" >Sing, Unburied, Sing</td>
#       <td id="T_dbf73_row0_col3" class="data row0 col3" >4592</td>
#       <td id="T_dbf73_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32920226-sing-unburied-sing">Goodreads</a></td>
#       <td id="T_dbf73_row0_col5" class="data row0 col5" ><img src="https://images.gr-assets.com/books/1499340866m/32920226.jpg" width=50></img></td>
#       <td id="T_dbf73_row0_col6" class="data row0 col6" >sing unburied sing</td>
#       <td id="T_dbf73_row0_col7" class="data row0 col7" >23.428571</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row1" class="row_heading level0 row1" >216</th>
#       <td id="T_dbf73_row1_col0" class="data row1 col0" >30753987</td>
#       <td id="T_dbf73_row1_col1" class="data row1 col1" >342</td>
#       <td id="T_dbf73_row1_col2" class="data row1 col2" >The Leavers</td>
#       <td id="T_dbf73_row1_col3" class="data row1 col3" >5602</td>
#       <td id="T_dbf73_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30753987-the-leavers">Goodreads</a></td>
#       <td id="T_dbf73_row1_col5" class="data row1 col5" ><img src="https://images.gr-assets.com/books/1489158974m/30753987.jpg" width=50></img></td>
#       <td id="T_dbf73_row1_col6" class="data row1 col6" >the leavers</td>
#       <td id="T_dbf73_row1_col7" class="data row1 col7" >20.878972</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row2" class="row_heading level0 row2" >441</th>
#       <td id="T_dbf73_row2_col0" class="data row2 col0" >33253215</td>
#       <td id="T_dbf73_row2_col1" class="data row2 col1" >236</td>
#       <td id="T_dbf73_row2_col2" class="data row2 col2" >The Heart's Invisible Furies</td>
#       <td id="T_dbf73_row2_col3" class="data row2 col3" >3629</td>
#       <td id="T_dbf73_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33253215-the-heart-s-invisible-furies">Goodreads</a></td>
#       <td id="T_dbf73_row2_col5" class="data row2 col5" ><img src="https://images.gr-assets.com/books/1490803456m/33253215.jpg" width=50></img></td>
#       <td id="T_dbf73_row2_col6" class="data row2 col6" >the hearts invisible furies</td>
#       <td id="T_dbf73_row2_col7" class="data row2 col7" >15.347479</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row3" class="row_heading level0 row3" >692</th>
#       <td id="T_dbf73_row3_col0" class="data row3 col0" >33280160</td>
#       <td id="T_dbf73_row3_col1" class="data row3 col1" >181</td>
#       <td id="T_dbf73_row3_col2" class="data row3 col2" >What We Lose</td>
#       <td id="T_dbf73_row3_col3" class="data row3 col3" >2250</td>
#       <td id="T_dbf73_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33280160-what-we-lose">Goodreads</a></td>
#       <td id="T_dbf73_row3_col5" class="data row3 col5" ><img src="https://images.gr-assets.com/books/1492235781m/33280160.jpg" width=50></img></td>
#       <td id="T_dbf73_row3_col6" class="data row3 col6" >what we lose</td>
#       <td id="T_dbf73_row3_col7" class="data row3 col7" >14.560444</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row4" class="row_heading level0 row4" >671</th>
#       <td id="T_dbf73_row4_col0" class="data row4 col0" >33621427</td>
#       <td id="T_dbf73_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_dbf73_row4_col2" class="data row4 col2" >Home Fire</td>
#       <td id="T_dbf73_row4_col3" class="data row4 col3" >2390</td>
#       <td id="T_dbf73_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33621427-home-fire">Goodreads</a></td>
#       <td id="T_dbf73_row4_col5" class="data row4 col5" ><img src="https://images.gr-assets.com/books/1500032043m/33621427.jpg" width=50></img></td>
#       <td id="T_dbf73_row4_col6" class="data row4 col6" >home fire</td>
#       <td id="T_dbf73_row4_col7" class="data row4 col7" >14.165690</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row5" class="row_heading level0 row5" >763</th>
#       <td id="T_dbf73_row5_col0" class="data row5 col0" >21032488</td>
#       <td id="T_dbf73_row5_col1" class="data row5 col1" >169</td>
#       <td id="T_dbf73_row5_col2" class="data row5 col2" >Doors of Stone (The Kingkiller Chronicle, #3)</td>
#       <td id="T_dbf73_row5_col3" class="data row5 col3" >2059</td>
#       <td id="T_dbf73_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/21032488-doors-of-stone">Goodreads</a></td>
#       <td id="T_dbf73_row5_col5" class="data row5 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_dbf73_row5_col6" class="data row5 col6" >doors of stone the kingkiller chronicle 3</td>
#       <td id="T_dbf73_row5_col7" class="data row5 col7" >13.871297</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row6" class="row_heading level0 row6" >990</th>
#       <td id="T_dbf73_row6_col0" class="data row6 col0" >30971664</td>
#       <td id="T_dbf73_row6_col1" class="data row6 col1" >142</td>
#       <td id="T_dbf73_row6_col2" class="data row6 col2" >Salt Houses</td>
#       <td id="T_dbf73_row6_col3" class="data row6 col3" >1474</td>
#       <td id="T_dbf73_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30971664-salt-houses">Goodreads</a></td>
#       <td id="T_dbf73_row6_col5" class="data row6 col5" ><img src="https://images.gr-assets.com/books/1474820735m/30971664.jpg" width=50></img></td>
#       <td id="T_dbf73_row6_col6" class="data row6 col6" >salt houses</td>
#       <td id="T_dbf73_row6_col7" class="data row6 col7" >13.679783</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row7" class="row_heading level0 row7" >71</th>
#       <td id="T_dbf73_row7_col0" class="data row7 col0" >30688435</td>
#       <td id="T_dbf73_row7_col1" class="data row7 col1" >533</td>
#       <td id="T_dbf73_row7_col2" class="data row7 col2" >Exit West</td>
#       <td id="T_dbf73_row7_col3" class="data row7 col3" >21378</td>
#       <td id="T_dbf73_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30688435-exit-west">Goodreads</a></td>
#       <td id="T_dbf73_row7_col5" class="data row7 col5" ><img src="https://images.gr-assets.com/books/1477324680m/30688435.jpg" width=50></img></td>
#       <td id="T_dbf73_row7_col6" class="data row7 col6" >exit west</td>
#       <td id="T_dbf73_row7_col7" class="data row7 col7" >13.288848</td>
#     </tr>
#     <tr>
#       <th id="T_dbf73_level0_row8" class="row_heading level0 row8" >251</th>
#       <td id="T_dbf73_row8_col0" class="data row8 col0" >32283423</td>
#       <td id="T_dbf73_row8_col1" class="data row8 col1" >321</td>
#       <td id="T_dbf73_row8_col2" class="data row8 col2" >American War</td>
#       <td id="T_dbf73_row8_col3" class="data row8 col3" >7776</td>
#       <td id="T_dbf73_row8_col4" class="data row8 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32283423-american-war">Goodreads</a></td>
#       <td id="T_dbf73_row8_col5" class="data row8 col5" ><img src="https://images.gr-assets.c
